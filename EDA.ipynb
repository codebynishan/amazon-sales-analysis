# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/nishanrana/Downloads/Amazon Sale Report.csv')
# Out:
# /var/folders/mq/8k37xryj0_n2cz69zl90f1gm0000gn/T/ipykernel_16602/1114246077.py:1: DtypeWarning: Columns (0: Unnamed: 22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/nishanrana/Downloads/Amazon Sale Report.csv')

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# 0            Set  ...      INR  647.62       MUMBAI  MAHARASHTRA
# 1          kurta  ...      INR  406.00    BENGALURU    KARNATAKA
# 2          kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA
# 3  Western Dress  ...      INR  753.33   PUDUCHERRY   PUDUCHERRY
# 4            Top  ...      INR  574.00      CHENNAI   TAMIL NADU
#
#   ship-postal-code  ship-country  \
# 0         400081.0            IN
# 1         560085.0            IN
# 2         410210.0            IN
# 3         605008.0            IN
# 4         600073.0            IN
#
#                                        promotion-ids    B2B  fulfilled-by  \
# 0                                                NaN  False     Easy Ship
# 1  Amazon PLCC Free-Financing Universal Merchant ...  False     Easy Ship
# 2       IN Core Free Shipping 2015/04/08 23-48-5-108   True           NaN
# 3                                                NaN  False     Easy Ship
# 4                                                NaN  False           NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %%
df.columns.tolist()
# Out:
# ['index',
#  'Order ID',
#  'Date',
#  'Status',
#  'Fulfilment',
#  'Sales Channel ',
#  'ship-service-level',
#  'Style',
#  'SKU',
#  'Category',
#  'Size',
#  'ASIN',
#  'Courier Status',
#  'Qty',
#  'currency',
#  'Amount',
#  'ship-city',
#  'ship-state',
#  'ship-postal-code',
#  'ship-country',
#  'promotion-ids',
#  'B2B',
#  'fulfilled-by',
#  'Unnamed: 22']

# %%
df.dtypes
# Out:
# index                   int64
# Order ID                  str
# Date                      str
# Status                    str
# Fulfilment                str
# Sales Channel             str
# ship-service-level        str
# Style                     str
# SKU                       str
# Category                  str
# Size                      str
# ASIN                      str
# Courier Status            str
# Qty                     int64
# currency                  str
# Amount                float64
# ship-city                 str
# ship-state                str
# ship-postal-code      float64
# ship-country              str
# promotion-ids             str
# B2B                      bool
# fulfilled-by              str
# Unnamed: 22            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  str
#  2   Date                128975 non-null  str
#  3   Status              128975 non-null  str
#  4   Fulfilment          128975 non-null  str
#  5   Sales Channel       128975 non-null  str
#  6   ship-service-level  128975 non-null  str
#  7   Style               128975 non-null  str
#  8   SKU                 128975 non-null  str
#  9   Category            128975 non-null  str
#  10  Size                128975 non-null  str
#  11  ASIN                128975 non-null  str
#  12  Courier Status      122103 non-null  str
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  str
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  str
#  17  ship-state          128942 non-null  str
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  str
#  20  promotion-ids       79822 non-null   str
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   str
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(1), str(18)
# memory usage: 22.8+ MB

# %%
missing = df.isnull().sum()
missing
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df))* 100
missing_percentage
# Out:
# index                  0.000000
# Order ID               0.000000
# Date                   0.000000
# Status                 0.000000
# Fulfilment             0.000000
# Sales Channel          0.000000
# ship-service-level     0.000000
# Style                  0.000000
# SKU                    0.000000
# Category               0.000000
# Size                   0.000000
# ASIN                   0.000000
# Courier Status         5.328164
# Qty                    0.000000
# currency               6.043807
# Amount                 6.043807
# ship-city              0.025586
# ship-state             0.025586
# ship-postal-code       0.025586
# ship-country           0.025586
# promotion-ids         38.110487
# B2B                    0.000000
# fulfilled-by          69.546811
# Unnamed: 22           38.030626
# dtype: float64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 128970    False
# 128971    False
# 128972    False
# 128973    False
# 128974    False
# Length: 121149, dtype: bool

# %%
df.drop(columns=['Unnamed: 22'],inplace=True)

# %%
df.drop(columns=['index'],inplace = True)

# %%
df.drop(columns=['fulfilled-by'],inplace=True)

# %%
df.drop(columns=['promotion-ids'],inplace=True)

# %%
df.dropna(subset=['currency','ship-city','ship-state','ship-postal-code','ship-country'],inplace = True)

# %%
df['Courier Status'] = df['Courier Status'].fillna(df['Courier Status'].mode()[0])

# %%
df['currency'] = df['currency'].fillna(df['currency'].mode()[0])

# %%
df['Amount'] = df['Amount'].fillna(df['Amount'].median())

# %%
df.isnull().sum()
# Out:
# index                 0
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# B2B                   0
# dtype: int64

# %%
df.shape
# Out:
# (121149, 21)

# %%
df.describe()
# Out:
#                index            Qty         Amount  ship-postal-code
# count  121149.000000  121149.000000  121149.000000     121149.000000
# mean    64483.736259       0.961246     648.573305     463652.687525
# std     37221.261564       0.214327     281.222115     191316.128616
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32290.000000       1.000000     449.000000     382421.000000
# 50%     64474.000000       1.000000     605.000000     500032.000000
# 75%     96681.000000       1.000000     788.000000     600021.000000
# max    128974.000000       8.000000    5584.000000     989898.000000

# %%
df['Date']=pd.to_datetime(df['Date'],format='%y-%m-%d')

# %%
df['ship-state'] = df['ship-state'].str.upper().str.strip()

# %%
df['ship-city'] = df['ship-'].str.upper().str.strip()

# %%
df['Date'].unique
# Out:
# <bound method Series.unique of 0        2022-04-30
# 1        2022-04-30
# 2        2022-04-30
# 3        2022-04-30
# 4        2022-04-30
#             ...
# 128970   2022-05-31
# 128971   2022-05-31
# 128972   2022-05-31
# 128973   2022-05-31
# 128974   2022-05-31
# Name: Date, Length: 121149, dtype: datetime64[us]>

# %%
df['Month'] = df['Date'].dt.month_name()

# %%
df['Year'] = df['Date'].dt.year

# %%
df['Day'] = df['Date'].dt.day_name()

# %%
df['Status'].unique
# Out:
# <bound method Series.unique of 0                            Cancelled
# 1         Shipped - Delivered to Buyer
# 2                              Shipped
# 3                            Cancelled
# 4                              Shipped
#                       ...
# 128970                         Shipped
# 128971                         Shipped
# 128972                         Shipped
# 128973                         Shipped
# 128974                         Shipped
# Name: Status, Length: 121149, dtype: str>

# %%
status_count = df['Status'].value_counts()
status_count
# Out:
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
status_percentage=(df['Status'].value_counts(normalize=True) * 100).round(2)
status_percentage
# Out:
# Status
# Shipped                          64.04
# Shipped - Delivered to Buyer     23.73
# Cancelled                         8.88
# Shipped - Returned to Seller      1.61
# Shipped - Picked Up               0.80
# Pending                           0.54
# Pending - Waiting for Pick Up     0.23
# Shipped - Returning to Seller     0.12
# Shipped - Out for Delivery        0.03
# Shipped - Rejected by Buyer       0.01
# Shipped - Lost in Transit         0.00
# Shipped - Damaged                 0.00
# Name: proportion, dtype: float64

# %%
df['Category'].value_counts()
# Out:
# Category
# Set              47031
# kurta            46700
# Western Dress    14703
# Top              10163
# Ethnic Dress      1093
# Blouse             881
# Bottom             420
# Saree              155
# Dupatta              3
# Name: count, dtype: int64

# %%
category_percentage =(df['Category'].value_counts(normalize=True)*100).round(2)
category_percentage
# Out:
# Category
# Set              38.99
# kurta            38.67
# Western Dress    12.02
# Top               8.24
# Ethnic Dress      0.90
# Blouse            0.72
# Bottom            0.34
# Saree             0.13
# Dupatta           0.00
# Name: proportion, dtype: float64

# %%
df['Fulfilment'].value_counts()
# Out:
# Fulfilment
# Amazon      89698
# Merchant    39277
# Name: count, dtype: int64

# %%
df['B2B'].value_counts()
# Out:
# B2B
# False    128104
# True        871
# Name: count, dtype: int64

# %%
df['ship-service-level'].value_counts()
# Out:
# ship-service-level
# Expedited    88615
# Standard     40360
# Name: count, dtype: int64

# %%
Total_revenue = df['Amount'].sum()
Total_revenue
# Out:
# np.float64(78592678.3)

# %%
category_revenue = df.groupby('Category')['Amount'].sum().sort_values(ascending=False)
category_revenue
# Out:
# Category
# Set              39204124.03
# kurta            21299546.70
# Western Dress    11216072.69
# Top               5347792.30
# Ethnic Dress       791217.66
# Blouse             458408.18
# Bottom             150667.98
# Saree              123933.76
# Dupatta               915.00
# Name: Amount, dtype: float64

# %%
df['ship-state'].value_counts().head(10)
# Out:
# ship-state
# MAHARASHTRA       22260
# KARNATAKA         17326
# TAMIL NADU        11483
# TELANGANA         11330
# UTTAR PRADESH     10638
# DELHI              6782
# KERALA             6585
# WEST BENGAL        5963
# ANDHRA PRADESH     5430
# Gujarat            4489
# Name: count, dtype: int64

# %%
df['ship-state'].nunique()
# Out:
# 69

# %%
top_state = df.groupby('ship-state')['Amount'].sum().sort_values(ascending=False).head(5)
top_state
# Out:
# ship-state
# MAHARASHTRA      13335534.14
# KARNATAKA        10481114.37
# TELANGANA         6916615.65
# UTTAR PRADESH     6816642.08
# TAMIL NADU        6515650.11
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(12, 6))

bars = plt.bar(status_counts.index, 
               status_counts.values, 
               color=['#2ecc71' if 'Shipped' in x 
                      else '#e74c3c' if 'Cancelled' in x 
                      else '#f39c12' for x in status_counts.index])


for i in range(len(bars)):
    plt.text(
        i,
        status_counts.values[i],
        f"{status_percent.values[i]:.1f}%\n({status_counts.values[i]:,})",
        ha='center',
        va='bottom'
    )

plt.title('Order status', 
          fontsize=14, fontweight='bold')
plt.xlabel('Order Status', fontweight='bold')
plt.ylabel('Number of Orders',fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.bar(category_revenue.index, category_revenue.values)
plt.title('Total revenue by product ', fontsize=14, fontweight='bold')
plt.xlabel('Category')
plt.ylabel('Total Revenue (₹)')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12, 5))
df['Amount'].plot(kind='hist', bins=50, color='teal', edgecolor='white')
plt.title('Distribution of order amounts', fontsize=14, fontweight='bold')
plt.xlabel('Order Amount (₹)')
plt.ylabel('Number of orders')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.bar(top_state.index, top_state.values, color='coral')
plt.title('Top 10 states by total revenue', fontsize=14, fontweight='bold')
plt.xlabel('State')
plt.ylabel('Total Revenue (₹)')
# plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()
