# %% [markdown]
# # importing libaries

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd

# %% [markdown]
# # connecting database

# %%
db_connection = 'mysql+pymysql://root:Nishan%402059@localhost/amazonsalesDB'
engine = create_engine(db_connection)

# %%
df.head()
# Out:
#    index              OrderId      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment SalesChannel ShipServiceLevel    Style              SKU  \
# 0   Merchant    Amazon.in         Standard   SET389   SET389-KR-NP-S
# 1   Merchant    Amazon.in         Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon    Amazon.in        Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant    Amazon.in         Standard    J0341       J0341-DR-L
# 4     Amazon    Amazon.in        Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount     ShipCity    ShipState  \
# ...

# %%
df = pd.read_pickle("cleaned_data.pkl")

# %% [markdown]
# # loading to database

# %%
df.to_sql(name='amazon_sales',
          con=engine,
          if_exists='replace',
          index=False
         )
# Out:
# 128942

# %% [markdown]
# # converting a pickle file into csv

# %%
df = pd.read_pickle('cleaned_data.pkl')

# %%
df.to_csv('amazon_sales_cleaned.csv', index=False,encoding='utf-8-sig')
